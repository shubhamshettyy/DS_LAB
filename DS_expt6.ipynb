# %% [markdown]
# ### Name: Shubham Shetty
# ### UID: 2018130050
# ### Batch: B

# %% [markdown]
# ## Objective:
# To perform time series analysis: identifying the nature of the phenomenon represented by the sequence of observations, and forecasting

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/Data Science Tutorials/time_series')

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Data Science Tutorials/time_series

# %%
import os
import warnings
warnings.filterwarnings('ignore')
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
# !pip install chart-studio
# Out:
# ...
#      |████████████████████████████████| 64 kB 1.9 MB/s
# ...
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11447 sha256=db1f65badc650968fdd38bb3bd8b93152c1fa6c25e9e063e556017067844245d
#   Stored in directory: /root/.cache/pip/wheels/f9/8d/8d/f6af3f7f9eea3553bc2fe6d53e4b287dad18b06a861ac56ddf
# Successfully built retrying
# ...

# %% [markdown]
# ## Importing libraries

# %%
# %matplotlib inline
from pylab import rcParams
from plotly import tools
import chart_studio.plotly as py
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.figure_factory as ff
import statsmodels.api as sm
from numpy.random import normal, seed
from scipy.stats import norm
import math
from sklearn.metrics import mean_squared_error
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# !ls
# Out:
# GOOGL_2006-01-01_to_2018-01-01.csv  pressure.csv
# humidity.csv			    stocks.png
# MSFT_2006-01-01_to_2018-01-01.csv

# %% [markdown]
# ### Reading google stock dataset

# %%
google = pd.read_csv('GOOGL_2006-01-01_to_2018-01-01.csv', index_col='Date', parse_dates=['Date'])
google.head()
# Out:
#               Open    High     Low   Close    Volume   Name
# Date
# 2006-01-03  211.47  218.05  209.32  217.83  13137450  GOOGL
# 2006-01-04  222.17  224.70  220.09  222.84  15292353  GOOGL
# 2006-01-05  223.22  226.00  220.97  225.85  10815661  GOOGL
# 2006-01-06  228.66  235.49  226.85  233.06  17759521  GOOGL
# 2006-01-09  233.44  236.94  230.70  233.68  12795837  GOOGL

# %% [markdown]
# ### Reading humidity dataset

# %%
humidity = pd.read_csv('humidity.csv', index_col='datetime', parse_dates=['datetime'])
humidity.tail()
# Out:
#                      Vancouver  Portland  San Francisco  Seattle  Los Angeles  \
# datetime
# 2017-11-29 20:00:00        NaN      81.0            NaN     93.0         24.0
# 2017-11-29 21:00:00        NaN      71.0            NaN     87.0         21.0
# 2017-11-29 22:00:00        NaN      71.0            NaN     93.0         23.0
# 2017-11-29 23:00:00        NaN      71.0            NaN     87.0         14.0
# 2017-11-30 00:00:00        NaN      76.0            NaN     75.0         56.0
#
#                      San Diego  Las Vegas  Phoenix  Albuquerque  Denver  ...  \
# datetime                                                                 ...
# 2017-11-29 20:00:00       72.0       18.0     68.0         37.0    18.0  ...
# 2017-11-29 21:00:00       72.0       18.0     73.0         34.0    12.0  ...
# 2017-11-29 22:00:00       68.0       17.0     60.0         32.0    15.0  ...
# 2017-11-29 23:00:00       63.0       17.0     33.0         30.0    28.0  ...
# ...

# %%
humidity.shape
# Out:
# (45252, 36)

# %%
humidity.isna().sum()
# Out:
# Vancouver            1826
# Portland              449
# San Francisco         942
# Seattle               289
# Los Angeles           152
# San Diego             344
# Las Vegas             842
# Phoenix              1308
# Albuquerque           710
# Denver               1808
# San Antonio           564
# Dallas                319
# Houston               121
# Kansas City           512
# Minneapolis           510
# Saint Louis          1289
# Chicago              1109
# Nashville             567
# Indianapolis          695
# Atlanta               422
# Detroit               862
# Jacksonville          209
# Charlotte             589
# Miami                1087
# Pittsburgh            522
# Toronto               728
# Philadelphia          624
# New York             1624
# Montreal             1696
# Boston                449
# Beersheba             859
# Tel Aviv District    1113
# Eilat                 970
# Haifa                 818
# Nahariyya             817
# ...

# %%
#Since humidity data has a lot of missing values we use fillna() to fill those values up
#We use ffill to use the last valid observation to fill the na values

humidity = humidity.iloc[1:]
humidity = humidity.fillna(method='ffill')
humidity.head()
# Out:
#                      Vancouver  Portland  San Francisco  Seattle  Los Angeles  \
# datetime
# 2012-10-01 13:00:00       76.0      81.0           88.0     81.0         88.0
# 2012-10-01 14:00:00       76.0      80.0           87.0     80.0         88.0
# 2012-10-01 15:00:00       76.0      80.0           86.0     80.0         88.0
# 2012-10-01 16:00:00       77.0      80.0           85.0     79.0         88.0
# 2012-10-01 17:00:00       78.0      79.0           84.0     79.0         88.0
#
#                      San Diego  Las Vegas  Phoenix  Albuquerque  Denver  ...  \
# datetime                                                                 ...
# 2012-10-01 13:00:00       82.0       22.0     23.0         50.0    62.0  ...
# 2012-10-01 14:00:00       81.0       21.0     23.0         49.0    62.0  ...
# 2012-10-01 15:00:00       81.0       21.0     23.0         49.0    62.0  ...
# 2012-10-01 16:00:00       81.0       21.0     23.0         49.0    62.0  ...
# ...

# %% [markdown]
# ### Plotting plots based on different frequencies

# %%
# asfreq method is used to convert a time series to a specified frequency.
# Here it is monthly frequency.
humidity["Kansas City"].asfreq('M').plot()
plt.title('Humidity in Kansas City over time(Monthly frequency)')
plt.show()

# %% [markdown]
# ### Trend of Google stocks from 2012 to 2015

# %%
google['2012':'2015'].plot(subplots=True, figsize=(10,12))
plt.title('Google stock attributes from 2012 to 2015')
plt.savefig('stocks.png')
plt.show()

# %% [markdown]
# ### Shifting and Lag

# %%
humidity["Vancouver"].asfreq('M').plot(legend=True)
shifted = humidity["Vancouver"].asfreq('M').shift(10).plot(legend=True)
shifted.legend(['Vancouver','Vancouver_lagged'])
plt.show()

# %% [markdown]
# ### Loading pressure dataset

# %%
pressure = pd.read_csv('pressure.csv', index_col='datetime', parse_dates=['datetime'])
pressure.tail()
# Out:
#                      Vancouver  Portland  San Francisco  Seattle  Los Angeles  \
# datetime
# 2017-11-29 20:00:00        NaN    1031.0            NaN   1030.0       1016.0
# 2017-11-29 21:00:00        NaN    1030.0            NaN   1030.0       1016.0
# 2017-11-29 22:00:00        NaN    1030.0            NaN   1029.0       1015.0
# 2017-11-29 23:00:00        NaN    1029.0            NaN   1028.0       1016.0
# 2017-11-30 00:00:00        NaN    1029.0            NaN   1028.0       1015.0
#
#                      San Diego  Las Vegas  Phoenix  Albuquerque  Denver  ...  \
# datetime                                                                 ...
# 2017-11-29 20:00:00     1017.0     1021.0   1018.0       1025.0  1016.0  ...
# 2017-11-29 21:00:00     1017.0     1020.0   1018.0       1024.0  1018.0  ...
# 2017-11-29 22:00:00     1016.0     1020.0   1017.0       1024.0  1018.0  ...
# 2017-11-29 23:00:00     1016.0     1020.0   1016.0       1024.0  1020.0  ...
# ...

# %%
#Cleaning the data
pressure = pressure.iloc[1:]
pressure = pressure.fillna(method='ffill')
pressure.tail()
# Out:
#                      Vancouver  Portland  San Francisco  Seattle  Los Angeles  \
# datetime
# 2017-11-29 20:00:00     1021.0    1031.0         1013.0   1030.0       1016.0
# 2017-11-29 21:00:00     1021.0    1030.0         1013.0   1030.0       1016.0
# 2017-11-29 22:00:00     1021.0    1030.0         1013.0   1029.0       1015.0
# 2017-11-29 23:00:00     1021.0    1029.0         1013.0   1028.0       1016.0
# 2017-11-30 00:00:00     1021.0    1029.0         1013.0   1028.0       1015.0
#
#                      San Diego  Las Vegas  Phoenix  Albuquerque  Denver  ...  \
# datetime                                                                 ...
# 2017-11-29 20:00:00     1017.0     1021.0   1018.0       1025.0  1016.0  ...
# 2017-11-29 21:00:00     1017.0     1020.0   1018.0       1024.0  1018.0  ...
# 2017-11-29 22:00:00     1016.0     1020.0   1017.0       1024.0  1018.0  ...
# 2017-11-29 23:00:00     1016.0     1020.0   1016.0       1024.0  1020.0  ...
# ...

# %%
pressure = pressure.fillna(method='bfill')
pressure.head()
# Out:
#                      Vancouver  Portland  San Francisco  Seattle  Los Angeles  \
# datetime
# 2012-10-01 13:00:00      807.0    1024.0         1009.0   1027.0       1013.0
# 2012-10-01 14:00:00      807.0    1024.0         1009.0   1027.0       1013.0
# 2012-10-01 15:00:00      807.0    1024.0         1009.0   1028.0       1013.0
# 2012-10-01 16:00:00      807.0    1024.0         1009.0   1028.0       1013.0
# 2012-10-01 17:00:00      807.0    1024.0         1009.0   1029.0       1013.0
#
#                      San Diego  Las Vegas  Phoenix  Albuquerque  Denver  ...  \
# datetime                                                                 ...
# 2012-10-01 13:00:00     1013.0     1018.0   1013.0       1024.0  1028.0  ...
# 2012-10-01 14:00:00     1013.0     1018.0   1013.0       1024.0  1028.0  ...
# 2012-10-01 15:00:00     1013.0     1018.0   1013.0       1024.0  1028.0  ...
# 2012-10-01 16:00:00     1013.0     1018.0   1013.0       1024.0  1028.0  ...
# ...

# %%
pressure.shape
# Out:
# (45252, 36)

# %% [markdown]
# ### Downsampling the frequency

# %%
# Downsample from hourly to 3 day frequency
pressure = pressure.resample('3D').mean()
pressure.head()
# Out:
#               Vancouver     Portland  San Francisco      Seattle  Los Angeles  \
# datetime
# 2012-10-01   931.627119  1022.644068    1010.881356  1031.271186  1011.627119
# 2012-10-04  1019.083333  1023.041667    1014.694444  1028.305556  1015.555556
# 2012-10-07  1013.930556  1017.444444    1016.597222  1018.736111  1013.416667
# 2012-10-10  1015.000000  1015.430556    1014.833333  1018.416667  1010.694444
# 2012-10-13  1008.152778  1018.111111    1021.069444  1015.930556  1017.277778
#
#               San Diego    Las Vegas      Phoenix  Albuquerque       Denver  \
# datetime
# 2012-10-01  1011.966102  1016.322034  1012.084746  1022.542373  1024.118644
# 2012-10-04  1016.277778  1013.194444  1014.097222  1019.972222  1020.666667
# 2012-10-07  1014.222222  1012.888889  1011.861111  1005.833333  1020.458333
# 2012-10-10  1014.013889  1000.166667  1005.611111   986.000000   984.486111
# 2012-10-13  1018.375000  1015.666667  1015.500000  1013.625000  1010.444444
#
# ...

# %%
pressure.shape
# Out:
# (629, 36)

# %%
pressure = pressure.resample('D').pad()
pressure.head()
# Out:
#               Vancouver     Portland  San Francisco      Seattle  Los Angeles  \
# datetime
# 2012-10-01   931.627119  1022.644068    1010.881356  1031.271186  1011.627119
# 2012-10-02   931.627119  1022.644068    1010.881356  1031.271186  1011.627119
# 2012-10-03   931.627119  1022.644068    1010.881356  1031.271186  1011.627119
# 2012-10-04  1019.083333  1023.041667    1014.694444  1028.305556  1015.555556
# 2012-10-05  1019.083333  1023.041667    1014.694444  1028.305556  1015.555556
#
#               San Diego    Las Vegas      Phoenix  Albuquerque       Denver  \
# datetime
# 2012-10-01  1011.966102  1016.322034  1012.084746  1022.542373  1024.118644
# 2012-10-02  1011.966102  1016.322034  1012.084746  1022.542373  1024.118644
# 2012-10-03  1011.966102  1016.322034  1012.084746  1022.542373  1024.118644
# 2012-10-04  1016.277778  1013.194444  1014.097222  1019.972222  1020.666667
# 2012-10-05  1016.277778  1013.194444  1014.097222  1019.972222  1020.666667
#
# ...

# %%
pressure.shape
# Out:
# (1885, 36)

# %% [markdown]
# *   Trend - Consistent upwards or downwards slope of a time series
# *   Seasonality - Clear periodic pattern of a time series(like sine funtion)
# *   Noise - Outliers or missing values

# %%
google["High"].plot(figsize=(16,8))

# %%
# For decomposition...
rcParams['figure.figsize'] = 11, 9
# The frequncy is annual
decomposed_google_volume = sm.tsa.seasonal_decompose(google["High"],freq=360)
figure = decomposed_google_volume.plot()
plt.show()

# %% [markdown]
# *   There is clearly an upward trend in the above plot.
# *   We see the uniform seasonal change.

# %%
# The original non-stationary plot
decomposed_google_volume.trend.plot()

# %%
decomposed_google_volume.trend.diff().plot()

# %% [markdown]
# ### Autocorelation of Google stocks

# %%
plot_acf(google["Close"],lags=50)
plt.title('Autocorrelation for Google Stocks Data - Close')
plt.show()

# %% [markdown]
# The autocorrelation value for Close prices of google stocks decreases with increase in lag. Upto 50 lags, the autocorrelatin value is still greater than 0.8. . As all lags are either close to 1 or at least greater than the confidence interval, they are statistically significant.

# %%
plot_acf(google["Volume"],lags=50)
plt.title('Autocorrelation for Google Stocks Data - Volume')
plt.show()

# %% [markdown]
# The autocorrelation value for volume of google stocks decreases with increase in lag. The descrease in autocorrelation values is not uniform. Upto 50 lags, the autocorrelatin value is around 0.4. . As all lags are greater than the confidence interval, they are statistically significant.

# %% [markdown]
# ### White noise

# %% [markdown]
# White noise has:
#
#
# *   Constant mean
# *   Constant variance
# *   The correlation between time series and its lagged version is not significant

# %%
# Plotting white noise
rcParams['figure.figsize'] = 16, 6
white_noise = np.random.normal(loc=0, scale=1, size=1000)
# loc is mean, scale is variance
plt.plot(white_noise)

# %%
# Plotting autocorrelation of white noise
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_acf(white_noise,lags=20)
plt.show()

# %% [markdown]
# We can see in the above plot that all lags are statistically insigficant as they lie inside the confidence interval(shaded portion).

# %%
# Plotting partial autocorrelation of white noise
plot_pacf(white_noise,lags=50)
plt.title("Partial Autocorrelation of White Noise")
plt.show()

# %% [markdown]
# We can see in the above plot that all lags are statistically insigficant as they lie inside the confidence interval.

# %% [markdown]
# ### Conclusion
#
#
# *   The stock values are increasing over the period hence this stock is profitable.
# *   The time series analysis of Google Stocks data shows that the stock value has a very high upward trend in a period of 3 to 4 years.
# *   The autocorrelation of google stock data suggests that it is statistically significant as the autocorrelation values lie outside of the confidence interval.
